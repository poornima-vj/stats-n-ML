# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/manishanker/Statistics_ML_26Aug/master/doubts/orange_dataset.csv")

# %%
df.describe()
# Out:
#        Unnamed: 0      Tree          age  circumference
# count   35.000000  35.00000    35.000000      35.000000
# mean    18.000000   3.00000   922.142857     115.857143
# std     10.246951   1.43486   491.864528      57.488179
# min      1.000000   1.00000   118.000000      30.000000
# 25%      9.500000   2.00000   484.000000      65.500000
# 50%     18.000000   3.00000  1004.000000     115.000000
# 75%     26.500000   4.00000  1372.000000     161.500000
# max     35.000000   5.00000  1582.000000     214.000000

# %%
df
# Out:
#     Unnamed: 0  Tree   age  circumference
# 0            1     1   118             30
# 1            2     1   484             58
# 2            3     1   664             87
# 3            4     1  1004            115
# 4            5     1  1231            120
# 5            6     1  1372            142
# 6            7     1  1582            145
# 7            8     2   118             33
# 8            9     2   484             69
# 9           10     2   664            111
# 10          11     2  1004            156
# 11          12     2  1231            172
# 12          13     2  1372            203
# 13          14     2  1582            203
# 14          15     3   118             30
# 15          16     3   484             51
# 16          17     3   664             75
# 17          18     3  1004            108
# 18          19     3  1231            115
# 19          20     3  1372            139
# 20          21     3  1582            140
# 21          22     4   118             32
# 22          23     4   484             62
# 23          24     4   664            112
# 24          25     4  1004            167
# 25          26     4  1231            179
# 26          27     4  1372            209
# 27          28     4  1582            214
# 28          29     5   118             30
# 29          30     5   484             49
# 30          31     5   664             81
# 31          32     5  1004            125
# 32          33     5  1231            142
# 33          34     5  1372            174
# 34          35     5  1582            177

# %%
print(df.shape)
# Out:
# (35, 4)

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# Tree             0
# age              0
# circumference    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Tree', 'age', 'circumference'], dtype='object')

# %%
# Plot scatter plot
plt.scatter(df["circumference"], df["age"])

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
model = LinearRegression()        #(normalize=False)

# %%
df["circumference"].values.reshape(-1,1)
# Out:
# array([[ 30],
#        [ 58],
#        [ 87],
#        [115],
#        [120],
#        [142],
#        [145],
#        [ 33],
#        [ 69],
#        [111],
#        [156],
#        [172],
#        [203],
#        [203],
#        [ 30],
#        [ 51],
#        [ 75],
#        [108],
#        [115],
#        [139],
#        [140],
#        [ 32],
#        [ 62],
#        [112],
#        [167],
#        [179],
#        [209],
#        [214],
#        [ 30],
#        [ 49],
#        [ 81],
#        [125],
#        [142],
#        [174],
#        [177]], dtype=int64)

# %%
# can ipredecit the age of orange fruit if we know the circumference

# %%
df["circumference"]
type(df["circumference"])
# Out:
# pandas.core.series.Series

# %%
X = df["circumference"].values.reshape(-1,1)
y = df["age"]

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
X
# Out:
# array([[ 30],
#        [ 58],
#        [ 87],
#        [115],
#        [120],
#        [142],
#        [145],
#        [ 33],
#        [ 69],
#        [111],
#        [156],
#        [172],
#        [203],
#        [203],
#        [ 30],
#        [ 51],
#        [ 75],
#        [108],
#        [115],
#        [139],
#        [140],
#        [ 32],
#        [ 62],
#        [112],
#        [167],
#        [179],
#        [209],
#        [214],
#        [ 30],
#        [ 49],
#        [ 81],
#        [125],
#        [142],
#        [174],
#        [177]], dtype=int64)

# %%
y
# Out:
# 0      118
# 1      484
# 2      664
# 3     1004
# 4     1231
# 5     1372
# 6     1582
# 7      118
# 8      484
# 9      664
# 10    1004
# 11    1231
# 12    1372
# 13    1582
# 14     118
# 15     484
# 16     664
# 17    1004
# 18    1231
# 19    1372
# 20    1582
# 21     118
# 22     484
# 23     664
# 24    1004
# 25    1231
# 26    1372
# 27    1582
# 28     118
# 29     484
# 30     664
# 31    1004
# 32    1231
# 33    1372
# 34    1582
# Name: age, dtype: int64

# %%
model.score(X, y)
# Out:
# 0.8345166945883684

# %%
y_pred = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, y_pred)
# Out:
# 38891.62301543713

# %%
df
# Out:
#     Unnamed: 0  Tree   age  circumference
# 0            1     1   118             30
# 1            2     1   484             58
# 2            3     1   664             87
# 3            4     1  1004            115
# 4            5     1  1231            120
# 5            6     1  1372            142
# 6            7     1  1582            145
# 7            8     2   118             33
# 8            9     2   484             69
# 9           10     2   664            111
# 10          11     2  1004            156
# 11          12     2  1231            172
# 12          13     2  1372            203
# 13          14     2  1582            203
# 14          15     3   118             30
# 15          16     3   484             51
# 16          17     3   664             75
# 17          18     3  1004            108
# 18          19     3  1231            115
# 19          20     3  1372            139
# 20          21     3  1582            140
# 21          22     4   118             32
# 22          23     4   484             62
# 23          24     4   664            112
# 24          25     4  1004            167
# 25          26     4  1231            179
# 26          27     4  1372            209
# 27          28     4  1582            214
# 28          29     5   118             30
# 29          30     5   484             49
# 30          31     5   664             81
# 31          32     5  1004            125
# 32          33     5  1231            142
# 33          34     5  1372            174
# 34          35     5  1582            177

# %%
#apply nomralisation on age and circumference coulumn  and apply liner regression

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df["age"] = scaler.fit_transform(df[["age"]])

# %%
df
# Out:
#     Unnamed: 0  Tree       age  circumference
# 0            1     1 -1.658755             30
# 1            2     1 -0.903784             58
# 2            3     1 -0.532487             87
# 3            4     1  0.168852            115
# 4            5     1  0.637099            120
# 5            6     1  0.927948            142
# 6            7     1  1.361128            145
# 7            8     2 -1.658755             33
# 8            9     2 -0.903784             69
# 9           10     2 -0.532487            111
# 10          11     2  0.168852            156
# 11          12     2  0.637099            172
# 12          13     2  0.927948            203
# 13          14     2  1.361128            203
# 14          15     3 -1.658755             30
# 15          16     3 -0.903784             51
# 16          17     3 -0.532487             75
# 17          18     3  0.168852            108
# 18          19     3  0.637099            115
# 19          20     3  0.927948            139
# 20          21     3  1.361128            140
# 21          22     4 -1.658755             32
# 22          23     4 -0.903784             62
# 23          24     4 -0.532487            112
# 24          25     4  0.168852            167
# 25          26     4  0.637099            179
# 26          27     4  0.927948            209
# 27          28     4  1.361128            214
# 28          29     5 -1.658755             30
# 29          30     5 -0.903784             49
# 30          31     5 -0.532487             81
# 31          32     5  0.168852            125
# 32          33     5  0.637099            142
# 33          34     5  0.927948            174
# 34          35     5  1.361128            177

# %%
df["circumference"] = scaler.fit_transform(df[["circumference"]])

# %%
df
# Out:
#     Unnamed: 0  Tree       age  circumference
# 0            1     1 -1.658755      -1.515278
# 1            2     1 -0.903784      -1.021111
# 2            3     1 -0.532487      -0.509295
# 3            4     1  0.168852      -0.015128
# 4            5     1  0.637099       0.073117
# 5            6     1  0.927948       0.461391
# 6            7     1  1.361128       0.514337
# 7            8     2 -1.658755      -1.462332
# 8            9     2 -0.903784      -0.826974
# 9           10     2 -0.532487      -0.085723
# 10          11     2  0.168852       0.708475
# 11          12     2  0.637099       0.990856
# 12          13     2  0.927948       1.537970
# 13          14     2  1.361128       1.537970
# 14          15     3 -1.658755      -1.515278
# 15          16     3 -0.903784      -1.144653
# 16          17     3 -0.532487      -0.721081
# 17          18     3  0.168852      -0.138669
# 18          19     3  0.637099      -0.015128
# 19          20     3  0.927948       0.408444
# 20          21     3  1.361128       0.426093
# 21          22     4 -1.658755      -1.479981
# 22          23     4 -0.903784      -0.950516
# 23          24     4 -0.532487      -0.068074
# 24          25     4  0.168852       0.902612
# 25          26     4  0.637099       1.114398
# 26          27     4  0.927948       1.643863
# 27          28     4  1.361128       1.732107
# 28          29     5 -1.658755      -1.515278
# 29          30     5 -0.903784      -1.179951
# 30          31     5 -0.532487      -0.615188
# 31          32     5  0.168852       0.161361
# 32          33     5  0.637099       0.461391
# 33          34     5  0.927948       1.026154
# 34          35     5  1.361128       1.079100

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
model = LinearRegression()

# %%
X = df["circumference"].values.reshape(-1,1)
y = df["age"]

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X, y)
# Out:
# 0.8345166945883684

# %%
y_pred = model.predict(X)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, y_pred)
# Out:
# 0.1654833054116316
